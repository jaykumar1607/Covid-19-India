# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set()

# %%
df=pd.read_csv('covid_project.csv',index_col='Sno')

# %%
df
# Out:
#           Date     Time State/UnionTerritory   Cured  Deaths  Confirmed
# Sno
# 0     30/01/20  6:00 PM               Kerala       0       0          1
# 1     31/01/20  6:00 PM               Kerala       0       0          1
# 2     01/02/20  6:00 PM               Kerala       0       0          2
# 3     02/02/20  6:00 PM               Kerala       0       0          3
# 4     03/02/20  6:00 PM               Kerala       0       0          3
# ...        ...      ...                  ...     ...     ...        ...
# 6273  14/09/20  8:00 AM            Telangana  127007     974     158513
# 6274  14/09/20  8:00 AM              Tripura   11536     200      19165
# 6275  14/09/20  8:00 AM          Uttarakhand   21040     414      31973
# 6276  14/09/20  8:00 AM        Uttar Pradesh  239485    4429     312036
# 6277  14/09/20  8:00 AM          West Bengal  175139    3945     202708
#
# [6278 rows x 6 columns]

# %%
a=df[df['Date']=='14/09/20']

# %% [markdown]
# ### Q. Top 5 states with the most Confirmed Cases till 14-09-20.

# %%
a.sort_values(by='Confirmed',ascending=False).head(5)
# Out:
#           Date     Time State/UnionTerritory   Cured  Deaths  Confirmed
# Sno
# 6262  14/09/20  8:00 AM          Maharashtra  740061   29531    1060308
# 6244  14/09/20  8:00 AM       Andhra Pradesh  467139    4912     567123
# 6272  14/09/20  8:00 AM           Tamil Nadu  447366    8381     502759
# 6258  14/09/20  8:00 AM            Karnataka  352958    7265     459445
# 6276  14/09/20  8:00 AM        Uttar Pradesh  239485    4429     312036

# %% [markdown]
# ### Q. Top 5 states with the most Deaths till 14-09-20.

# %%
a.sort_values(by='Deaths',ascending=False).head(5)
# Out:
#           Date     Time State/UnionTerritory   Cured  Deaths  Confirmed
# Sno
# 6262  14/09/20  8:00 AM          Maharashtra  740061   29531    1060308
# 6272  14/09/20  8:00 AM           Tamil Nadu  447366    8381     502759
# 6258  14/09/20  8:00 AM            Karnataka  352958    7265     459445
# 6244  14/09/20  8:00 AM       Andhra Pradesh  467139    4912     567123
# 6251  14/09/20  8:00 AM                Delhi  184748    4744     218304

# %% [markdown]
# ### Q. Top 5 states with the most Cured Patients till 14-09-20.

# %%
a.sort_values(by='Cured',ascending=False).head(5)
# Out:
#           Date     Time State/UnionTerritory   Cured  Deaths  Confirmed
# Sno
# 6262  14/09/20  8:00 AM          Maharashtra  740061   29531    1060308
# 6244  14/09/20  8:00 AM       Andhra Pradesh  467139    4912     567123
# 6272  14/09/20  8:00 AM           Tamil Nadu  447366    8381     502759
# 6258  14/09/20  8:00 AM            Karnataka  352958    7265     459445
# 6276  14/09/20  8:00 AM        Uttar Pradesh  239485    4429     312036

# %%
a.loc[:,'current_total']=a['Confirmed']-(a['Cured']+a['Deaths'])
# DONT FORGET TO USE .LOC
# Out:
# /home/jay/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /home/jay/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# ### Q. Top 5 states with the most Active Cases till 14-09-20.

# %%
a.sort_values(by='current_total',ascending=False).head(5)
# Out:
#           Date     Time State/UnionTerritory   Cured  Deaths  Confirmed  \
# Sno
# 6262  14/09/20  8:00 AM          Maharashtra  740061   29531    1060308
# 6258  14/09/20  8:00 AM            Karnataka  352958    7265     459445
# 6244  14/09/20  8:00 AM       Andhra Pradesh  467139    4912     567123
# 6276  14/09/20  8:00 AM        Uttar Pradesh  239485    4429     312036
# 6272  14/09/20  8:00 AM           Tamil Nadu  447366    8381     502759
#
#       current_total
# Sno
# 6262         290716
# 6258          99222
# 6244          95072
# 6276          68122
# 6272          47012

# %% [markdown]
# ### Q. What is the total number of 'Active' Covid-19 patients on 14th of September in India.

# %%
a['current_total'].sum()
# Out:
# 986598

# %% [markdown]
# ### NOTE: We can see from the table that 'Maharashtra' is the worst State in India in terms of the spread of the Covid-19 Virus

# %% [markdown]
# ### Q. Confirmed Corona Virus cases trend in Maharashra since March.

# %%
mh=df[df['State/UnionTerritory']=='Maharashtra']

# %%
mh.head(1)
# Out:
#          Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# Sno
# 76   09/03/20  6:00 PM          Maharashtra      0       0          2

# %%
mh.loc[:,'Date']=mh['Date']+'20'
# Out:
# /home/jay/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
mh.head()
# Out:
#            Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# Sno
# 76   09/03/2020  6:00 PM          Maharashtra      0       0          2
# 91   10/03/2020  6:00 PM          Maharashtra      0       0          5
# 97   11/03/2020  6:00 PM          Maharashtra      0       0          2
# 120  12/03/2020  6:00 PM          Maharashtra      0       0         11
# 133  13/03/2020  6:00 PM          Maharashtra      0       0         14

# %%
mh.loc[:,'Date']=pd.to_datetime(mh['Date'],format='%d/%m/%Y')
# Out:
# /home/jay/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
mh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 76 to 6262
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  190 non-null    datetime64[ns]
#  1   Time                  190 non-null    object
#  2   State/UnionTerritory  190 non-null    object
#  3   Cured                 190 non-null    int64
#  4   Deaths                190 non-null    int64
#  5   Confirmed             190 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 10.4+ KB

# %%
mh.head()
# Out:
#           Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# Sno
# 76  2020-03-09  6:00 PM          Maharashtra      0       0          2
# 91  2020-03-10  6:00 PM          Maharashtra      0       0          5
# 97  2020-03-11  6:00 PM          Maharashtra      0       0          2
# 120 2020-03-12  6:00 PM          Maharashtra      0       0         11
# 133 2020-03-13  6:00 PM          Maharashtra      0       0         14

# %% [markdown]
# #### NOTE: Since Maharashtra is the state which is affected in the worst way, we can further look into more details and compare it with other states.

# %% [markdown]
# ### Q. Maharastra's Covid-19 cases growth since March of 2020.

# %%
sns.lineplot(y=mh['Confirmed'],x=mh['Date'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed'>

# %%
df.loc[:,'Date']=df['Date']+'20'

# %%
df.loc[:,'Date']=pd.to_datetime(df['Date'],format='%d/%m/%Y')

# %%
df.head()
# Out:
#           Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# Sno
# 0   2020-01-30  6:00 PM               Kerala      0       0          1
# 1   2020-01-31  6:00 PM               Kerala      0       0          1
# 2   2020-02-01  6:00 PM               Kerala      0       0          2
# 3   2020-02-02  6:00 PM               Kerala      0       0          3
# 4   2020-02-03  6:00 PM               Kerala      0       0          3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6278 entries, 0 to 6277
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  6278 non-null   datetime64[ns]
#  1   Time                  6278 non-null   object
#  2   State/UnionTerritory  6278 non-null   object
#  3   Cured                 6278 non-null   int64
#  4   Deaths                6278 non-null   int64
#  5   Confirmed             6278 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 343.3+ KB

# %%
t5=df[(df['State/UnionTerritory']=='Maharashtra') | (df['State/UnionTerritory']=='Karnataka') | (df['State/UnionTerritory']=='Uttar Pradesh') | (df['State/UnionTerritory']=='Andhra Pradesh') | (df['State/UnionTerritory']=='Tamil Nadu')]

# %%
t5['State/UnionTerritory'].unique()
# Out:
# array(['Uttar Pradesh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Andhra Pradesh'], dtype=object)

# %% [markdown]
# ### Q. Growth in Covid-19 cases of top 5 most affected states since March of 2020.

# %%
plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
sns.lineplot(y=t5['Confirmed'],x=t5['Date'],hue=t5['State/UnionTerritory'],palette='rainbow')
plt.legend(bbox_to_anchor=[1,1.02])

# %%
rec=df[df['Date']=='2020-09-14']

# %%
rec.head()
# Out:
#            Date     Time         State/UnionTerritory   Cured  Deaths  \
# Sno
# 6243 2020-09-14  8:00 AM  Andaman and Nicobar Islands    3243      51
# 6244 2020-09-14  8:00 AM               Andhra Pradesh  467139    4912
# 6245 2020-09-14  8:00 AM            Arunachal Pradesh    4379      10
# 6246 2020-09-14  8:00 AM                        Assam  113133     469
# 6247 2020-09-14  8:00 AM                        Bihar  143350     822
#
#       Confirmed
# Sno
# 6243       3546
# 6244     567123
# 6245       6121
# 6246     141763
# 6247     158285

# %%
rec['recovery_rate']=rec['Cured']/rec['Confirmed']*100
# Out:
# /home/jay/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Q. Top 10 states with the best 'Recovery Rate' in India.

# %%
rec.sort_values(by='recovery_rate',ascending=False)[['State/UnionTerritory','recovery_rate']].head(10)
# Out:
#                   State/UnionTerritory  recovery_rate
# Sno
# 6243       Andaman and Nicobar Islands      91.455161
# 6250  Dadra & Nagar Haveli/Daman & Diu      90.637523
# 6247                             Bihar      90.564488
# 6272                        Tamil Nadu      88.982196
# 6277                       West Bengal      86.399649
# 6251                             Delhi      84.628775
# 6253                           Gujarat      82.716300
# 6270                         Rajasthan      82.530662
# 6244                    Andhra Pradesh      82.369962
# 6273                         Telangana      80.124028

# %% [markdown]
# ### Q. Top 10 states with the highest 'Mortality Rate' in India.

# %%
rec['mortality_rate']=rec['Deaths']/rec['Confirmed']*100
# Out:
# /home/jay/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
rec.sort_values(by='mortality_rate',ascending=False)[['State/UnionTerritory','mortality_rate']].head(10)
# Out:
#      State/UnionTerritory  mortality_rate
# Sno
# 6269               Punjab        2.956864
# 6253              Gujarat        2.828194
# 6262          Maharashtra        2.785134
# 6251                Delhi        2.173116
# 6261       Madhya Pradesh        1.996668
# 6277          West Bengal        1.946149
# 6268           Puducherry        1.941209
# 6272           Tamil Nadu        1.667001
# 6256    Jammu and Kashmir        1.623041
# 6258            Karnataka        1.581256

# %% [markdown]
# ### Q. Mapping confirmed cases across the States/Union Territories in India

# %%
import geopandas as gpd

# %%
map_df=gpd.read_file('Igismap/Indian_States.shp')

# %%
latest=df[df['Date']=='2020-09-14'][['State/UnionTerritory','Confirmed','Cured','Deaths']]

# %%
map_df.sort_values(by='st_nm')
# Out:
#                        st_nm  \
# 0   Andaman & Nicobar Island
# 35            Andhra Pradesh
# 1         Arunanchal Pradesh
# 2                      Assam
# 3                      Bihar
# 4                 Chandigarh
# 5               Chhattisgarh
# 6     Dadara & Nagar Havelli
# 7                Daman & Diu
# 8                        Goa
# 9                    Gujarat
# 10                   Haryana
# 11          Himachal Pradesh
# 12           Jammu & Kashmir
# 13                 Jharkhand
# 14                 Karnataka
# 15                    Kerala
# 16               Lakshadweep
# 17            Madhya Pradesh
# 18               Maharashtra
# 19                   Manipur
# 20                 Meghalaya
# 21                   Mizoram
# 23              NCT of Delhi
# 22                  Nagaland
# 34                    Odisha
# 24                Puducherry
# 25                    Punjab
# 26                 Rajasthan
# 27                    Sikkim
# 28                Tamil Nadu
# ...

# %%
latest
# Out:
#                   State/UnionTerritory  Confirmed   Cured  Deaths
# Sno
# 6243       Andaman and Nicobar Islands       3546    3243      51
# 6244                    Andhra Pradesh     567123  467139    4912
# 6245                 Arunachal Pradesh       6121    4379      10
# 6246                             Assam     141763  113133     469
# 6247                             Bihar     158285  143350     822
# 6248                        Chandigarh       7991    5170      93
# 6249                      Chhattisgarh      63991   31931     555
# 6250  Dadra & Nagar Haveli/Daman & Diu       2745    2488       2
# 6251                             Delhi     218304  184748    4744
# 6252                               Goa      24592   19129     290
# 6253                           Gujarat     113500   93883    3210
# 6254                           Haryana      93641   72587     975
# 6255                  Himachal Pradesh       9555    6114      77
# ...

# %%
map_df.loc[1,'st_nm']='Arunachal Pradesh'

# %%
map_df.loc[0,'st_nm']='Andaman and Nicobar Islands'

# %%
map_df.loc[23,'st_nm']='Delhi'

# %%
map_df.loc[12,'st_nm']='Jammu and Kashmir'

# %%
map_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   st_nm     36 non-null     object
#  1   geometry  36 non-null     geometry
# dtypes: geometry(1), object(1)
# memory usage: 704.0+ bytes

# %%
merged_map=map_df.set_index('st_nm').join(latest.set_index('State/UnionTerritory'))

# %%
merged_map.drop(labels=['Dadara & Nagar Havelli','Daman & Diu','Lakshadweep'],inplace=True)

# %%
merged_map
# Out:
#                                                                       geometry  \
# st_nm
# Andaman and Nicobar Islands  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Arunachal Pradesh            POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# Assam                        MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# Bihar                        MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# Chandigarh                   POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# Chhattisgarh                 POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# Goa                          MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# Gujarat                      MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# Haryana                      POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# Himachal Pradesh             POLYGON ((76.79634 33.25490, 76.80351 33.25275...
# Jammu and Kashmir            POLYGON ((74.73451 37.02068, 74.73647 37.01937...
# ...

# %%
fig,axes=plt.subplots(1,figsize=(18,10))
axes.axis('off')
axes.set_title('Confirmed Corona Virus Cases In India',fontdict={'fontsize':24})
merged_map.plot(column='Confirmed',cmap='viridis',ax=axes,legend=True,lw=0.8,edgecolor='0.8')
plt.show()

# %% [markdown]
# ## M.L Application:

# %% [markdown]
# ### Q. Predicting the growth of the virus in accordance to the "confirmed cases" in India given in the dataset.

# %%
ml=df

# %%
ml.head()
# Out:
#           Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# Sno
# 0   2020-01-30  6:00 PM               Kerala      0       0          1
# 1   2020-01-31  6:00 PM               Kerala      0       0          1
# 2   2020-02-01  6:00 PM               Kerala      0       0          2
# 3   2020-02-02  6:00 PM               Kerala      0       0          3
# 4   2020-02-03  6:00 PM               Kerala      0       0          3

# %%
# Summing the confirmed cases on day to day basis
ml=ml.groupby(by='Date').sum().reset_index()

# %%
ml.head()
# Out:
#         Date  Cured  Deaths  Confirmed
# 0 2020-01-30      0       0          1
# 1 2020-01-31      0       0          1
# 2 2020-02-01      0       0          2
# 3 2020-02-02      0       0          3
# 4 2020-02-03      0       0          3

# %%
import datetime as dt

# %%
# To convert datetime into numerical data
ml['Date']=ml['Date'].map(dt.datetime.toordinal)

# %%
ml.drop(['Cured','Deaths'],inplace=True,axis=1)

# %%
ml.head()
# Out:
#      Date  Confirmed
# 0  737454          1
# 1  737455          1
# 2  737456          2
# 3  737457          3
# 4  737458          3
